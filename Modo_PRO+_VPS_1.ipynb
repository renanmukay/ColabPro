# %%
#@title **2. Criar Usuário**
# !setterm -foreground blue
import os,sys,time
 
username = "user" #@param {type:"string"}
password = "root" #@param {type:"string"}

print('SSENDAM ROTSEVNI')
print("User is being created...")
 
# Creation of user
os.system(f"useradd -m {username}")
 
# Add user to sudo group
os.system(f"adduser {username} sudo")
    
# Set password of user to 'root'
os.system(f"echo '{username}:{password}' | sudo chpasswd")
 
# Change default shell from sh to bash
os.system("sed -i 's/\/bin\/sh/\/bin\/bash/g' /etc/passwd")

for i in range(101):
        time.sleep(0.1)
        sys.stdout.write("\rLoading script: %d%%" % i)
        while (i > 101):
            os.system('cls')
        sys.stdout.flush()
print("\nUser created successfully!")

# %%
#@title **3. Instalação de VPS**
#@markdown  Instalação leva de 4 a 5 minutos.
# !setterm -foreground blue
import os
import subprocess
 
#@markdown  Primeiro: Vá para o site http://remotedesktop.google.com/headless

#@markdown  Segundo: Copie o comando para autenticar o VPS e cole no CRP.

CRP = "" #@param {type:"string"}
 
#@markdown O pin abaixo dará a você "acesso ao Google Remote."
Pin = 123456 #@param {type: "integer"}
 
 
class CRD:
    def __init__(self):
        os.system("apt update")
        self.installCRD()
        self.installDesktopEnvironment()
        self.installGoogleChorme()
        self.finish()
 
    @staticmethod
    def installCRD():
        print("Install Chrome Remote Desktop")
        subprocess.run(['wget', 'https://dl.google.com/linux/direct/chrome-remote-desktop_current_amd64.deb'], stdout=subprocess.PIPE)
        subprocess.run(['dpkg', '--install', 'chrome-remote-desktop_current_amd64.deb'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', '--assume-yes', '--fix-broken'], stdout=subprocess.PIPE)
 
    @staticmethod
    def installDesktopEnvironment():
        print("Install Desktop Environment")
        os.system("export DEBIAN_FRONTEND=noninteractive")
        os.system("apt install --assume-yes xfce4 desktop-base xfce4-terminal")
        os.system("bash -c 'echo \"exec /etc/X11/Xsession /usr/bin/xfce4-session\" > /etc/chrome-remote-desktop-session'")
        os.system("apt remove --assume-yes gnome-terminal")
        os.system("apt install --assume-yes xscreensaver")
        os.system("systemctl disable lightdm.service")
 
    @staticmethod
    def installGoogleChorme():
        print("Install Google Chrome")
        subprocess.run(["wget", "https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb"], stdout=subprocess.PIPE)
        subprocess.run(["dpkg", "--install", "google-chrome-stable_current_amd64.deb"], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', '--assume-yes', '--fix-broken'], stdout=subprocess.PIPE)
 
    @staticmethod
    def finish():
        print("Finishing")
        os.system(f"adduser {username} chrome-remote-desktop")
        command = f"{CRP} --pin={Pin}"
        os.system(f"su - {username} -c '{command}'")
        os.system("service chrome-remote-desktop start")
        print("VPS successfully created.")
 
 
try:
    if username:
        if CRP == "":
            print("Enter the authentication code from the link provided.")
        elif len(str(Pin)) < 6:
            print("Enter a PIN with 6 digits or more.")
        else:
            CRD()
except NameError as e:
    print("username not found!")
    print("Run the user creation script")

# %%
#@title **🚀🚀🚀 Modo PRO+ GPU 🚀🚀🚀** { display-mode: "form" }
#@markdown - **MODELOS DE GPU**
#@markdown - K80 💩
#@markdown - P4 😕
#@markdown - T4 😀
#@markdown - P100 🥰
#@markdown - V100 🚀

gpu_info = ! nvidia-smi -L
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('Tesla V100...') >=0:
  print(gpu_info)
  exit()
else :
  print(gpu_info)

from IPython.display import HTML
from subprocess import getoutput
s = getoutput('nvidia-smi -L')
if 'K80' in s:
  gpu = 'Conectado com VGA Tesla K80 💩'
elif 'P4' in s:
  gpu = 'Conectado com VGA Tesla P4 😕'
elif 'T4' in s:
  gpu = 'Conectado com VGA Tesla T4 😀'
elif 'P100' in s:
  gpu = 'Conectado com VGA Tesla P100 🥰'
elif 'V100' in s:
  gpu = 'Conectado com VGA Tesla V100 🚀'
display(HTML(f"<h1>{gpu}</h1>"))

Nome = "PC04" #@param {type:'string'}
print("💻 Computador", Nome ,"Conectado")
# !wget -qO- ifconfig.co/ip

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
if ram_gb > 20:
  print('⚠️ MEMÓRIA ALTA ATIVADA ⚠️')

import time

named_tuple = time.localtime()
time_string = time.strftime("%d/%m/%Y às %H:%M:%S", named_tuple)

print("⏱ Iniciado em:", time_string)

import time
Ativar = True #@param {type:'boolean'}
!
temps = 0
sec = 3600
while(temps < 2592000):
  if(temps == sec):
    sec += 3600
    x = (temps/60)/60
    print("⏳ Você está on-line a",x,"hora(s). Faltam",24-x,"Horas ⌛️")
  time.sleep(1)
  temps += 1

#@markdown ---

#@markdown - ⚠️ **RAM ALTA ATIVADA** ⚠️

#@markdown  Primeiro: Pressione CTRL + SHIFT + I e Rode o Script "Auto-click".

#@markdown  Segundo: Rode o Script VPS.
